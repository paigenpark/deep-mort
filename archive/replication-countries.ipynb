# %% [markdown]
# This is a replication of Richman and Wuthrich's 2019 paper: A neural network extension of the Lee-Carter model to multiple populations

# %%
#!pip install keras
#!pip install tensorflow
#!pip install pandas
#!pip install matplotlib
#!pip install scikit-learn
import tensorflow as tf
tfkl = tf.keras.layers
import csv
import numpy as np
import pandas as pd
import os as os
import matplotlib.pyplot as plt
#from keras.layers import Input, Embedding, Flatten, Dense, BatchNormalization, Dropout, concatenate
#from keras.models import Model
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
# loading in data
data = []
ages = []
countries = []
genders = []

with open("../data/Mx_1x1/hmd.csv", "r") as file:
    reader = csv.reader(file,delimiter=",")
    for row_index, row in enumerate(reader):
        if row_index == 0:
            print(row)
        if row_index >= 1:
            year, age, country, gender, rate = row
            year = int(year)
            try:
                age = int(age)
            except:
                age = -1
            if country not in countries:
                countries.append(country)
            country = countries.index(country)
            if gender not in genders:
                genders.append(gender)
            gender = genders.index(gender)
            try:
                rate = float(rate)
            except:
                rate = -1
            if rate > 1:
                rate = 1
            if age != -1 and rate != -1 and age <= 99:
                data.append([year, age, country, gender, rate])

data = np.array(data)
# Out:
# ['Year', 'Age', 'Country', 'Gender', 'Mortality_rate']

# %%
# eda
plt.figure()
plt.hist(data[:, 0])
plt.xlabel("year")
plt.show()

plt.figure()
plt.hist(data[:, 1])
plt.xlabel("age")
plt.show()

plt.figure()
plt.hist(data[:, 2], bins=len(countries))
plt.xlabel("countries")
country_position = np.arange(len(countries))
plt.xticks(country_position, countries, rotation=90)
plt.show()

plt.figure()
plt.hist(data[:, 3], bins=len(genders))
plt.xlabel("genders")
gender_position = np.arange(len(genders))
plt.xticks(gender_position, genders, rotation=90)
plt.show()

plt.figure()
plt.hist(data[:, 4], bins=50)
plt.xlabel("mortality rate")
plt.show()

# %%
training_index = np.logical_and(data[:, 0] >= 1950, data[:, 0] <= 1990)
training_data = data[training_index, :]
test_index = np.logical_and(data[:, 0] > 1990, data[:, 0] <= 2000)
test_data = data[test_index, :]

# %%
training_data = tf.convert_to_tensor(training_data)
test_data = tf.convert_to_tensor(test_data)
training_data = tf.cast(training_data, tf.float32)
test_data = tf.cast(test_data, tf.float32)
num_train = training_data.shape[0]
num_test = test_data.shape[0]

# %%
def get_data(index, mode):
    if mode == "train":
        rand_index = tf.random.uniform([],minval=0, maxval=num_train, dtype=tf.int32) 
        entry = training_data[rand_index, :]
    elif mode == "not_random":
        entry = test_data[index, :]
    else: 
        rand_index = tf.random.uniform([],minval=0, maxval=num_test, dtype=tf.int32)
        entry = test_data[rand_index, :]
    year, age, country, gender, rate = entry[0], entry[1], entry[2], entry[3], entry[4]
    year = (year - 1950)/50
    age = tf.cast(age, tf.int32)
    country = tf.cast(country, tf.int32)
    gender = tf.cast(gender, tf.int32)
    year = tf.reshape(year, [1])
    age = tf.reshape(age, [1])
    country = tf.reshape(country, [1])
    gender = tf.reshape(gender, [1])
    rate = tf.reshape(rate, [1])
    return (year, age, country, gender), rate

# %%
dataset_train = tf.data.Dataset.from_tensor_slices(np.arange(10000))
dataset_train = dataset_train.repeat()
dataset_train = dataset_train.map(lambda x: get_data(x, mode="train"), num_parallel_calls=4)
dataset_train = dataset_train.batch(256)
dataset_train = dataset_train.prefetch(buffer_size=512)

dataset_test = tf.data.Dataset.from_tensor_slices(np.arange(10000))
dataset_test = dataset_test.repeat()
dataset_test = dataset_test.map(lambda x: get_data(x, mode="test"), num_parallel_calls=4)
dataset_test = dataset_test.batch(256)
dataset_test = dataset_test.prefetch(buffer_size=512)

# %%
for (year, age, country, gender), rate in dataset_test:
    break
    
batch_index = 0
print("year:", year.numpy()[batch_index, 0])
print("age:", age.numpy()[batch_index, 0])
print("country:", country.numpy()[batch_index, 0])
print("gender:", gender.numpy()[batch_index, 0])
print("rate:", rate.numpy()[batch_index, 0])
# Out:
# year: 0.84
# age: 83
# country: 0
# gender: 0
# rate: 0.076129

# %%
# defining inputs 
year = tfkl.Input(shape=(1,), dtype='float32', name='Year')
age =  tfkl.Input(shape=(1,), dtype='int32', name='Age')
country = tfkl.Input(shape=(1,), dtype='int32', name='Country')
gender = tfkl.Input(shape=(1,), dtype='int32', name='Gender')

# defining embedding layers 
age_embed = tfkl.Embedding(input_dim=100, output_dim=5, input_length=1, name='Age_embed')(age)
age_embed = tfkl.Flatten()(age_embed)

gender_embed = tfkl.Embedding(input_dim=2, output_dim=5, input_length=1, name='Gender_embed')(gender)
gender_embed = tfkl.Flatten()(gender_embed)

country_embed = tfkl.Embedding(input_dim=38, output_dim=5, input_length=1, name='Country_embed')(country)
country_embed = tfkl.Flatten()(country_embed)

# create feature vector 
x = tfkl.Concatenate()([year, age_embed, gender_embed, country_embed])
x1 = x

# setting up middle layers 
x = tfkl.Dense(128, activation='tanh')(x)
x = tfkl.BatchNormalization()(x)
x = tfkl.Dropout(0.05)(x)

x = tfkl.Dense(128, activation='tanh')(x)
x = tfkl.BatchNormalization()(x)
x = tfkl.Dropout(0.05)(x)

x = tfkl.Dense(128, activation='tanh')(x)
x = tfkl.BatchNormalization()(x)
x = tfkl.Dropout(0.05)(x)

x = tfkl.Dense(128, activation='tanh')(x)
x = tfkl.BatchNormalization()(x)
x = tfkl.Dropout(0.05)(x)

# setting up output layer 
x = tfkl.Concatenate()([x1, x])
x = tfkl.Dense(128, activation='tanh')(x)
x = tfkl.BatchNormalization()(x)
x = tfkl.Dropout(0.05)(x)
x = tfkl.Dense(1, activation='sigmoid', name='final')(x)

# creating the model 
model = tf.keras.Model(inputs=[year, age, country, gender], outputs=[x])

# %%
# compiling the model
model.compile(loss='mse', optimizer='adam')

# %%
model.fit(dataset_train, steps_per_epoch=1000, validation_data=dataset_test, validation_steps=500, epochs=50, verbose=2)
# Out:
# Epoch 1/50
# 1000/1000 - 8s - loss: 0.0148 - val_loss: 8.4952e-04 - 8s/epoch - 8ms/step
# Epoch 2/50
# 1000/1000 - 7s - loss: 0.0021 - val_loss: 6.8867e-04 - 7s/epoch - 7ms/step
# Epoch 3/50
# 1000/1000 - 8s - loss: 0.0014 - val_loss: 6.4596e-04 - 8s/epoch - 8ms/step
# Epoch 4/50
# 1000/1000 - 8s - loss: 0.0012 - val_loss: 6.7406e-04 - 8s/epoch - 8ms/step
# Epoch 5/50
# 1000/1000 - 8s - loss: 0.0011 - val_loss: 9.2870e-04 - 8s/epoch - 8ms/step
# Epoch 6/50
# 1000/1000 - 8s - loss: 9.5992e-04 - val_loss: 5.0117e-04 - 8s/epoch - 8ms/step
# Epoch 7/50
# 1000/1000 - 8s - loss: 9.5670e-04 - val_loss: 5.2216e-04 - 8s/epoch - 8ms/step
# Epoch 8/50
# 1000/1000 - 8s - loss: 9.0640e-04 - val_loss: 5.3212e-04 - 8s/epoch - 8ms/step
# Epoch 9/50
# 1000/1000 - 8s - loss: 9.3053e-04 - val_loss: 6.4266e-04 - 8s/epoch - 8ms/step
# Epoch 10/50
# 1000/1000 - 8s - loss: 8.6934e-04 - val_loss: 4.7258e-04 - 8s/epoch - 8ms/step
# Epoch 11/50
# 1000/1000 - 10s - loss: 9.0932e-04 - val_loss: 4.7596e-04 - 10s/epoch - 10ms/step
# Epoch 12/50
# 1000/1000 - 9s - loss: 9.0257e-04 - val_loss: 5.3450e-04 - 9s/epoch - 9ms/step
# Epoch 13/50
# 1000/1000 - 9s - loss: 8.7357e-04 - val_loss: 4.8338e-04 - 9s/epoch - 9ms/step
# Epoch 14/50
# 1000/1000 - 9s - loss: 8.7035e-04 - val_loss: 4.8002e-04 - 9s/epoch - 9ms/step
# Epoch 15/50
# 1000/1000 - 9s - loss: 8.3727e-04 - val_loss: 4.8289e-04 - 9s/epoch - 9ms/step
# Epoch 16/50
# 1000/1000 - 9s - loss: 8.3102e-04 - val_loss: 4.7159e-04 - 9s/epoch - 9ms/step
# Epoch 17/50
# 1000/1000 - 9s - loss: 8.4839e-04 - val_loss: 4.7642e-04 - 9s/epoch - 9ms/step
# Epoch 18/50
# 1000/1000 - 9s - loss: 8.4988e-04 - val_loss: 5.6442e-04 - 9s/epoch - 9ms/step
# Epoch 19/50
# 1000/1000 - 9s - loss: 8.8149e-04 - val_loss: 4.6946e-04 - 9s/epoch - 9ms/step
# Epoch 20/50
# 1000/1000 - 9s - loss: 8.5165e-04 - val_loss: 4.5825e-04 - 9s/epoch - 9ms/step
# Epoch 21/50
# 1000/1000 - 9s - loss: 8.0615e-04 - val_loss: 4.6502e-04 - 9s/epoch - 9ms/step
# Epoch 22/50
# 1000/1000 - 9s - loss: 8.1918e-04 - val_loss: 4.6299e-04 - 9s/epoch - 9ms/step
# Epoch 23/50
# 1000/1000 - 9s - loss: 8.0304e-04 - val_loss: 4.6914e-04 - 9s/epoch - 9ms/step
# Epoch 24/50
# 1000/1000 - 9s - loss: 8.4694e-04 - val_loss: 4.5636e-04 - 9s/epoch - 9ms/step
# Epoch 25/50
# 1000/1000 - 9s - loss: 8.3693e-04 - val_loss: 5.0852e-04 - 9s/epoch - 9ms/step
# Epoch 26/50
# 1000/1000 - 9s - loss: 8.1228e-04 - val_loss: 4.7415e-04 - 9s/epoch - 9ms/step
# Epoch 27/50
# 1000/1000 - 9s - loss: 8.2045e-04 - val_loss: 4.7127e-04 - 9s/epoch - 9ms/step
# Epoch 28/50
# 1000/1000 - 10s - loss: 8.2587e-04 - val_loss: 4.5294e-04 - 10s/epoch - 10ms/step
# Epoch 29/50
# 1000/1000 - 9s - loss: 7.9511e-04 - val_loss: 4.3351e-04 - 9s/epoch - 9ms/step
# Epoch 30/50
# 1000/1000 - 9s - loss: 8.1390e-04 - val_loss: 4.5798e-04 - 9s/epoch - 9ms/step
# Epoch 31/50
# 1000/1000 - 9s - loss: 8.2831e-04 - val_loss: 5.6430e-04 - 9s/epoch - 9ms/step
# Epoch 32/50
# 1000/1000 - 9s - loss: 8.2811e-04 - val_loss: 4.2590e-04 - 9s/epoch - 9ms/step
# Epoch 33/50
# 1000/1000 - 9s - loss: 7.8265e-04 - val_loss: 4.5743e-04 - 9s/epoch - 9ms/step
# Epoch 34/50
# 1000/1000 - 9s - loss: 8.2500e-04 - val_loss: 4.6282e-04 - 9s/epoch - 9ms/step
# Epoch 35/50
# 1000/1000 - 11s - loss: 8.2086e-04 - val_loss: 4.8126e-04 - 11s/epoch - 11ms/step
# Epoch 36/50
# 1000/1000 - 10s - loss: 7.9083e-04 - val_loss: 5.1818e-04 - 10s/epoch - 10ms/step
# Epoch 37/50
# 1000/1000 - 10s - loss: 8.0521e-04 - val_loss: 4.8114e-04 - 10s/epoch - 10ms/step
# Epoch 38/50
# 1000/1000 - 12s - loss: 8.4163e-04 - val_loss: 4.7930e-04 - 12s/epoch - 12ms/step
# Epoch 39/50
# 1000/1000 - 10s - loss: 7.7400e-04 - val_loss: 4.9678e-04 - 10s/epoch - 10ms/step
# Epoch 40/50
# 1000/1000 - 11s - loss: 8.2917e-04 - val_loss: 4.4451e-04 - 11s/epoch - 11ms/step
# Epoch 41/50
# 1000/1000 - 9s - loss: 8.0510e-04 - val_loss: 5.0816e-04 - 9s/epoch - 9ms/step
# Epoch 42/50
# 1000/1000 - 9s - loss: 8.1212e-04 - val_loss: 4.6414e-04 - 9s/epoch - 9ms/step
# Epoch 43/50
# 1000/1000 - 9s - loss: 7.7221e-04 - val_loss: 4.7489e-04 - 9s/epoch - 9ms/step
# Epoch 44/50
# 1000/1000 - 9s - loss: 7.6980e-04 - val_loss: 4.9492e-04 - 9s/epoch - 9ms/step
# Epoch 45/50
# 1000/1000 - 9s - loss: 7.9236e-04 - val_loss: 4.8050e-04 - 9s/epoch - 9ms/step
# Epoch 46/50
# 1000/1000 - 9s - loss: 8.2276e-04 - val_loss: 4.9011e-04 - 9s/epoch - 9ms/step
# Epoch 47/50
# 1000/1000 - 9s - loss: 8.0438e-04 - val_loss: 4.5441e-04 - 9s/epoch - 9ms/step
# Epoch 48/50
# 1000/1000 - 8s - loss: 7.9808e-04 - val_loss: 4.5786e-04 - 8s/epoch - 8ms/step
# Epoch 49/50
# 1000/1000 - 8s - loss: 7.7049e-04 - val_loss: 4.5307e-04 - 8s/epoch - 8ms/step
# Epoch 50/50
# 1000/1000 - 9s - loss: 8.4306e-04 - val_loss: 4.6076e-04 - 9s/epoch - 9ms/step

# %%
dataset_test2 = tf.data.Dataset.from_tensor_slices(np.arange(10000))
dataset_test2 = dataset_test2.repeat()
dataset_test2 = dataset_test2.map(lambda x: get_data(x, mode="not_random"), num_parallel_calls=4)
dataset_test2 = dataset_test2.batch(100)
dataset_test2 = dataset_test2.prefetch(buffer_size=512)

# %%
j=0
for inputs, output in dataset_test2:
    j += 1
    if j > 3000:
        break
predictions = model(inputs)

# %%
plt.figure()
plt.plot(predictions[:, 0], label="prediction")
plt.plot(output[:, 0], label="truth")
plt.legend()
plt.show()

# %%
output.shape
predictions.shape
# Out:
# TensorShape([100, 1])
