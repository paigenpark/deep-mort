# %% [markdown]
# ## Freeze-and-Train Deep Ensemble for Mortality Prediction

# %% [markdown]
# ### Import packages

# %%
import tensorflow as tf
import numpy as np
import os as os
tfkl = tf.keras.layers
import random

# %% [markdown]
# ### Import functions

# %%
import training_functions_freeze_uncertainty as training_functions
import importlib

importlib.reload(training_functions)
# Out:
# <module 'training_functions_freeze_uncertainty' from '/Users/paigepark/Desktop/repos/deep-mort/code/training_functions_freeze_uncertainty.py'>

# %% [markdown]
# ### Import data

# %% [markdown]
# #### Country data

# %%
country_training = np.loadtxt('../data/country_training.txt')
country_test = np.loadtxt('../data/country_test.txt')

# %%
country_training.shape
# Out:
# (359594, 5)

# %% [markdown]
# #### All Country Model (Freeze-and-Train Ensemble)

# %%
# prep data
country_train_prepped = training_functions.prep_data(country_training, mode="train", changeratetolog=True)
country_test_prepped = training_functions.prep_data(country_test, mode="test", changeratetolog=True)

# %%
# get the proper geography input dimension for model set up 
unique_vals = tf.unique(country_training[:, 0]).y
country_geo_dim = np.array(tf.size(unique_vals)).item()
country_geo_dim = country_geo_dim + 50

# %%
# Prepare input features once (shared across all iterations)
training_input_features = (
    tf.convert_to_tensor((country_training[:, 2] - 1959) / 60, dtype=tf.float32),
    tf.convert_to_tensor(country_training[:, 3], dtype=tf.float32),
    tf.convert_to_tensor(country_training[:, 0], dtype=tf.float32),
    tf.convert_to_tensor(country_training[:, 1], dtype=tf.float32),
)

test_input_features = (
    tf.convert_to_tensor((country_test[:, 2] - 1959) / 60, dtype=tf.float32),
    tf.convert_to_tensor(country_test[:, 3], dtype=tf.float32),
    tf.convert_to_tensor(country_test[:, 0], dtype=tf.float32),
    tf.convert_to_tensor(country_test[:, 1], dtype=tf.float32),
)

inputs_train = np.delete(country_training, 4, axis=1)
inputs_test = np.delete(country_test, 4, axis=1)

# Storage for ensemble combination
M = 5
train_mus = []
train_vars = []
test_mus = []
test_vars = []

# %%
# train each ensemble member with different seeds, saving predictions and models per member
for i in range(1, M + 1):
    # Set reproducible seeds per iteration
    np.random.seed(i)
    tf.random.set_seed(i)
    random.seed(i)
    os.environ['PYTHONHASHSEED'] = str(i)

    model_country, loss_info_country = training_functions.run_freeze_ensemble_model(
        country_train_prepped, country_test_prepped, country_geo_dim,
        epochs_mean=20, epochs_var=10, steps_per_epoch=1405, lograte=True
    )

    # Get raw predictions: shape (N, 2) = [mu, raw_variance]
    raw_train_preds = model_country.predict(training_input_features)
    raw_test_preds = model_country.predict(test_input_features)

    # Split into mu and variance (applying softplus + floor to raw variance)
    train_mu = raw_train_preds[:, 0:1]
    train_var = np.log(1.0 + np.exp(raw_train_preds[:, 1:2])) + 1e-6

    test_mu = raw_test_preds[:, 0:1]
    test_var = np.log(1.0 + np.exp(raw_test_preds[:, 1:2])) + 1e-6

    # Store for ensemble combination
    train_mus.append(train_mu)
    train_vars.append(train_var)
    test_mus.append(test_mu)
    test_vars.append(test_var)

    # Save individual member predictions: [geo, gender, year, age, mu, variance]
    training_predictions = np.column_stack((inputs_train, train_mu, train_var))
    test_predictions = np.column_stack((inputs_test, test_mu, test_var))

    model_country.save(f"../models/dl_country_freeze_ensemble_{i}.keras")
    np.savetxt(f"../data/dl_country_freeze_fitted_{i}.txt", training_predictions)
    np.savetxt(f"../data/dl_country_freeze_forecast_{i}.txt", test_predictions)

    print(f"Ensemble member {i} complete | val NLL: {loss_info_country:.6f}")
# Out:
# Epoch 1/20
# 1405/1405 - 6s - 4ms/step - loss: 2.0418 - val_loss: 0.1912 - learning_rate: 1.0000e-03
# Epoch 2/20
# 1405/1405 - 5s - 3ms/step - loss: 0.3390 - val_loss: 0.2274 - learning_rate: 1.0000e-03
# Epoch 3/20
# 1405/1405 - 5s - 4ms/step - loss: 0.2545 - val_loss: 0.2303 - learning_rate: 1.0000e-03
# Epoch 4/20
# 1405/1405 - 5s - 3ms/step - loss: 0.2198 - val_loss: 0.2616 - learning_rate: 1.0000e-03
# Epoch 5/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1916 - val_loss: 0.1698 - learning_rate: 2.5000e-04
# Epoch 6/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1882 - val_loss: 0.1711 - learning_rate: 2.5000e-04
# Epoch 7/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1886 - val_loss: 0.1790 - learning_rate: 2.5000e-04
# Epoch 8/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1887 - val_loss: 0.2144 - learning_rate: 2.5000e-04
# Epoch 9/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1786 - val_loss: 0.1676 - learning_rate: 6.2500e-05
# Epoch 10/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1725 - val_loss: 0.1435 - learning_rate: 6.2500e-05
# Epoch 11/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1715 - val_loss: 0.1662 - learning_rate: 6.2500e-05
# Epoch 12/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1722 - val_loss: 0.1465 - learning_rate: 6.2500e-05
# Epoch 13/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1671 - val_loss: 0.1592 - learning_rate: 6.2500e-05
# Epoch 14/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1675 - val_loss: 0.1699 - learning_rate: 1.5625e-05
# Epoch 15/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1680 - val_loss: 0.1872 - learning_rate: 1.5625e-05
# Epoch 16/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1708 - val_loss: 0.1692 - learning_rate: 1.5625e-05
# Epoch 17/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1709 - val_loss: 0.1628 - learning_rate: 3.9063e-06
# Epoch 18/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1706 - val_loss: 0.1812 - learning_rate: 3.9063e-06
# Epoch 19/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1704 - val_loss: 0.1623 - learning_rate: 3.9063e-06
# Epoch 20/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1694 - val_loss: 0.1691 - learning_rate: 9.7656e-07
# Epoch 1/10
# 1405/1405 - 4s - 3ms/step - loss: -6.4809e-01 - val_loss: -7.1439e-01 - learning_rate: 1.0000e-03
# Epoch 2/10
# 1405/1405 - 4s - 3ms/step - loss: -7.7921e-01 - val_loss: -8.0733e-01 - learning_rate: 1.0000e-03
# Epoch 3/10
# 1405/1405 - 4s - 3ms/step - loss: -7.7848e-01 - val_loss: -7.2250e-01 - learning_rate: 1.0000e-03
# Epoch 4/10
# 1405/1405 - 4s - 3ms/step - loss: -7.8216e-01 - val_loss: -7.8280e-01 - learning_rate: 1.0000e-03
# Epoch 5/10
# 1405/1405 - 4s - 3ms/step - loss: -7.7821e-01 - val_loss: -7.5079e-01 - learning_rate: 1.0000e-03
# Epoch 6/10
# 1405/1405 - 4s - 3ms/step - loss: -7.8891e-01 - val_loss: -8.0504e-01 - learning_rate: 2.5000e-04
# Epoch 7/10
# 1405/1405 - 4s - 3ms/step - loss: -7.9551e-01 - val_loss: -7.9846e-01 - learning_rate: 2.5000e-04
# Epoch 8/10
# 1405/1405 - 4s - 3ms/step - loss: -7.9355e-01 - val_loss: -6.9410e-01 - learning_rate: 2.5000e-04
# Epoch 9/10
# 1405/1405 - 4s - 3ms/step - loss: -7.9408e-01 - val_loss: -8.1493e-01 - learning_rate: 6.2500e-05
# Epoch 10/10
# 1405/1405 - 4s - 3ms/step - loss: -7.9992e-01 - val_loss: -8.0124e-01 - learning_rate: 6.2500e-05
# 11238/11238 ━━━━━━━━━━━━━━━━━━━━ 4s 318us/step
# 2482/2482 ━━━━━━━━━━━━━━━━━━━━ 1s 312us/step
# Ensemble member 1 complete | val NLL: -0.814929
# Epoch 1/20
# 1405/1405 - 6s - 4ms/step - loss: 2.0133 - val_loss: 0.5012 - learning_rate: 1.0000e-03
# Epoch 2/20
# 1405/1405 - 5s - 3ms/step - loss: 0.3376 - val_loss: 0.2026 - learning_rate: 1.0000e-03
# Epoch 3/20
# 1405/1405 - 5s - 4ms/step - loss: 0.2537 - val_loss: 0.2287 - learning_rate: 1.0000e-03
# Epoch 4/20
# 1405/1405 - 5s - 3ms/step - loss: 0.2220 - val_loss: 0.2318 - learning_rate: 1.0000e-03
# Epoch 5/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1983 - val_loss: 0.1883 - learning_rate: 1.0000e-03
# Epoch 6/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1897 - val_loss: 0.1746 - learning_rate: 1.0000e-03
# Epoch 7/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1847 - val_loss: 0.1753 - learning_rate: 1.0000e-03
# Epoch 8/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1798 - val_loss: 0.1940 - learning_rate: 1.0000e-03
# Epoch 9/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1795 - val_loss: 0.1841 - learning_rate: 1.0000e-03
# Epoch 10/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1687 - val_loss: 0.1729 - learning_rate: 2.5000e-04
# Epoch 11/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1661 - val_loss: 0.1498 - learning_rate: 2.5000e-04
# Epoch 12/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1643 - val_loss: 0.1552 - learning_rate: 2.5000e-04
# Epoch 13/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1638 - val_loss: 0.1712 - learning_rate: 2.5000e-04
# Epoch 14/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1665 - val_loss: 0.1623 - learning_rate: 2.5000e-04
# Epoch 15/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1503 - val_loss: 0.1745 - learning_rate: 6.2500e-05
# Epoch 16/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1592 - val_loss: 0.1691 - learning_rate: 6.2500e-05
# Epoch 17/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1585 - val_loss: 0.1733 - learning_rate: 6.2500e-05
# Epoch 18/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1527 - val_loss: 0.1482 - learning_rate: 1.5625e-05
# Epoch 19/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1550 - val_loss: 0.1756 - learning_rate: 1.5625e-05
# Epoch 20/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1563 - val_loss: 0.1641 - learning_rate: 1.5625e-05
# Epoch 1/10
# 1405/1405 - 4s - 3ms/step - loss: -6.7488e-01 - val_loss: -8.9504e-01 - learning_rate: 1.0000e-03
# Epoch 2/10
# 1405/1405 - 4s - 3ms/step - loss: -9.2853e-01 - val_loss: -9.5686e-01 - learning_rate: 1.0000e-03
# Epoch 3/10
# 1405/1405 - 4s - 3ms/step - loss: -9.8771e-01 - val_loss: -9.3446e-01 - learning_rate: 1.0000e-03
# Epoch 4/10
# 1405/1405 - 4s - 3ms/step - loss: -9.8789e-01 - val_loss: -9.2278e-01 - learning_rate: 1.0000e-03
# Epoch 5/10
# 1405/1405 - 4s - 3ms/step - loss: -9.8489e-01 - val_loss: -8.6907e-01 - learning_rate: 1.0000e-03
# Epoch 6/10
# 1405/1405 - 4s - 3ms/step - loss: -9.8871e-01 - val_loss: -9.1969e-01 - learning_rate: 2.5000e-04
# Epoch 7/10
# 1405/1405 - 4s - 3ms/step - loss: -9.7662e-01 - val_loss: -9.0849e-01 - learning_rate: 2.5000e-04
# Epoch 8/10
# 1405/1405 - 4s - 3ms/step - loss: -9.7140e-01 - val_loss: -9.2324e-01 - learning_rate: 2.5000e-04
# Epoch 9/10
# 1405/1405 - 4s - 3ms/step - loss: -9.8205e-01 - val_loss: -9.4723e-01 - learning_rate: 6.2500e-05
# Epoch 10/10
# 1405/1405 - 4s - 3ms/step - loss: -9.9518e-01 - val_loss: -9.3305e-01 - learning_rate: 6.2500e-05
# 11238/11238 ━━━━━━━━━━━━━━━━━━━━ 3s 299us/step
# 2482/2482 ━━━━━━━━━━━━━━━━━━━━ 1s 293us/step
# Ensemble member 2 complete | val NLL: -0.956859
# Epoch 1/20
# 1405/1405 - 6s - 4ms/step - loss: 2.0945 - val_loss: 0.2609 - learning_rate: 1.0000e-03
# Epoch 2/20
# 1405/1405 - 5s - 3ms/step - loss: 0.3250 - val_loss: 0.1970 - learning_rate: 1.0000e-03
# Epoch 3/20
# 1405/1405 - 5s - 3ms/step - loss: 0.2463 - val_loss: 0.2071 - learning_rate: 1.0000e-03
# Epoch 4/20
# 1405/1405 - 5s - 3ms/step - loss: 0.2188 - val_loss: 0.1769 - learning_rate: 1.0000e-03
# Epoch 5/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1988 - val_loss: 0.1709 - learning_rate: 1.0000e-03
# Epoch 6/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1938 - val_loss: 0.1897 - learning_rate: 1.0000e-03
# Epoch 7/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1871 - val_loss: 0.1978 - learning_rate: 1.0000e-03
# Epoch 8/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1796 - val_loss: 0.1865 - learning_rate: 1.0000e-03
# Epoch 9/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1701 - val_loss: 0.1970 - learning_rate: 2.5000e-04
# Epoch 10/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1604 - val_loss: 0.1567 - learning_rate: 2.5000e-04
# Epoch 11/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1668 - val_loss: 0.1636 - learning_rate: 2.5000e-04
# Epoch 12/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1640 - val_loss: 0.1870 - learning_rate: 2.5000e-04
# Epoch 13/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1640 - val_loss: 0.1838 - learning_rate: 2.5000e-04
# Epoch 14/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1607 - val_loss: 0.1683 - learning_rate: 6.2500e-05
# Epoch 15/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1586 - val_loss: 0.1608 - learning_rate: 6.2500e-05
# Epoch 16/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1595 - val_loss: 0.1540 - learning_rate: 6.2500e-05
# Epoch 17/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1595 - val_loss: 0.1568 - learning_rate: 6.2500e-05
# Epoch 18/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1623 - val_loss: 0.1851 - learning_rate: 6.2500e-05
# Epoch 19/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1597 - val_loss: 0.1679 - learning_rate: 6.2500e-05
# Epoch 20/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1595 - val_loss: 0.1565 - learning_rate: 1.5625e-05
# Epoch 1/10
# 1405/1405 - 4s - 3ms/step - loss: -7.2161e-01 - val_loss: -8.9720e-01 - learning_rate: 1.0000e-03
# Epoch 2/10
# 1405/1405 - 4s - 3ms/step - loss: -8.8362e-01 - val_loss: -9.8361e-01 - learning_rate: 1.0000e-03
# Epoch 3/10
# 1405/1405 - 4s - 3ms/step - loss: -9.1537e-01 - val_loss: -9.4146e-01 - learning_rate: 1.0000e-03
# Epoch 4/10
# 1405/1405 - 4s - 3ms/step - loss: -9.2715e-01 - val_loss: -9.3180e-01 - learning_rate: 1.0000e-03
# Epoch 5/10
# 1405/1405 - 4s - 3ms/step - loss: -9.5785e-01 - val_loss: -9.6126e-01 - learning_rate: 1.0000e-03
# Epoch 6/10
# 1405/1405 - 4s - 3ms/step - loss: -9.6150e-01 - val_loss: -9.1686e-01 - learning_rate: 2.5000e-04
# Epoch 7/10
# 1405/1405 - 4s - 3ms/step - loss: -9.4479e-01 - val_loss: -9.2685e-01 - learning_rate: 2.5000e-04
# Epoch 8/10
# 1405/1405 - 4s - 3ms/step - loss: -9.5856e-01 - val_loss: -9.3719e-01 - learning_rate: 2.5000e-04
# Epoch 9/10
# 1405/1405 - 4s - 3ms/step - loss: -9.4635e-01 - val_loss: -9.7586e-01 - learning_rate: 6.2500e-05
# Epoch 10/10
# 1405/1405 - 4s - 3ms/step - loss: -9.4673e-01 - val_loss: -9.5925e-01 - learning_rate: 6.2500e-05
# 11238/11238 ━━━━━━━━━━━━━━━━━━━━ 3s 299us/step
# 2482/2482 ━━━━━━━━━━━━━━━━━━━━ 1s 304us/step
# Ensemble member 3 complete | val NLL: -0.983613
# Epoch 1/20
# 1405/1405 - 6s - 4ms/step - loss: 2.0534 - val_loss: 0.2452 - learning_rate: 1.0000e-03
# Epoch 2/20
# 1405/1405 - 5s - 3ms/step - loss: 0.3327 - val_loss: 0.2898 - learning_rate: 1.0000e-03
# Epoch 3/20
# 1405/1405 - 5s - 3ms/step - loss: 0.2496 - val_loss: 0.1637 - learning_rate: 1.0000e-03
# Epoch 4/20
# 1405/1405 - 5s - 3ms/step - loss: 0.2214 - val_loss: 0.2357 - learning_rate: 1.0000e-03
# Epoch 5/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1960 - val_loss: 0.1748 - learning_rate: 1.0000e-03
# Epoch 6/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1899 - val_loss: 0.2075 - learning_rate: 1.0000e-03
# Epoch 7/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1738 - val_loss: 0.1621 - learning_rate: 2.5000e-04
# Epoch 8/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1746 - val_loss: 0.1737 - learning_rate: 2.5000e-04
# Epoch 9/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1735 - val_loss: 0.1718 - learning_rate: 2.5000e-04
# Epoch 10/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1715 - val_loss: 0.2005 - learning_rate: 2.5000e-04
# Epoch 11/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1659 - val_loss: 0.1710 - learning_rate: 6.2500e-05
# Epoch 12/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1654 - val_loss: 0.1863 - learning_rate: 6.2500e-05
# Epoch 13/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1665 - val_loss: 0.1697 - learning_rate: 6.2500e-05
# Epoch 14/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1647 - val_loss: 0.1595 - learning_rate: 1.5625e-05
# Epoch 15/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1675 - val_loss: 0.1540 - learning_rate: 1.5625e-05
# Epoch 16/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1576 - val_loss: 0.1772 - learning_rate: 1.5625e-05
# Epoch 17/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1623 - val_loss: 0.1684 - learning_rate: 1.5625e-05
# Epoch 18/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1588 - val_loss: 0.1803 - learning_rate: 1.5625e-05
# Epoch 19/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1631 - val_loss: 0.2163 - learning_rate: 3.9063e-06
# Epoch 20/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1636 - val_loss: 0.1653 - learning_rate: 3.9063e-06
# Epoch 1/10
# 1405/1405 - 5s - 3ms/step - loss: -6.7131e-01 - val_loss: -7.5539e-01 - learning_rate: 1.0000e-03
# Epoch 2/10
# 1405/1405 - 4s - 3ms/step - loss: -8.0693e-01 - val_loss: -8.2748e-01 - learning_rate: 1.0000e-03
# Epoch 3/10
# 1405/1405 - 4s - 3ms/step - loss: -8.4892e-01 - val_loss: -8.5369e-01 - learning_rate: 1.0000e-03
# Epoch 4/10
# 1405/1405 - 4s - 3ms/step - loss: -8.7437e-01 - val_loss: -8.3300e-01 - learning_rate: 1.0000e-03
# Epoch 5/10
# 1405/1405 - 4s - 3ms/step - loss: -8.7100e-01 - val_loss: -7.9851e-01 - learning_rate: 1.0000e-03
# Epoch 6/10
# 1405/1405 - 4s - 3ms/step - loss: -8.7429e-01 - val_loss: -8.4950e-01 - learning_rate: 1.0000e-03
# Epoch 7/10
# 1405/1405 - 4s - 3ms/step - loss: -8.8407e-01 - val_loss: -8.5751e-01 - learning_rate: 2.5000e-04
# Epoch 8/10
# 1405/1405 - 4s - 3ms/step - loss: -8.6807e-01 - val_loss: -8.4426e-01 - learning_rate: 2.5000e-04
# Epoch 9/10
# 1405/1405 - 4s - 3ms/step - loss: -8.8377e-01 - val_loss: -8.7868e-01 - learning_rate: 2.5000e-04
# Epoch 10/10
# 1405/1405 - 4s - 3ms/step - loss: -8.8981e-01 - val_loss: -8.7225e-01 - learning_rate: 2.5000e-04
# 11238/11238 ━━━━━━━━━━━━━━━━━━━━ 3s 301us/step
# 2482/2482 ━━━━━━━━━━━━━━━━━━━━ 1s 296us/step
# Ensemble member 4 complete | val NLL: -0.878677
# Epoch 1/20
# 1405/1405 - 6s - 4ms/step - loss: 2.0137 - val_loss: 0.3337 - learning_rate: 1.0000e-03
# Epoch 2/20
# 1405/1405 - 5s - 4ms/step - loss: 0.3200 - val_loss: 0.2047 - learning_rate: 1.0000e-03
# Epoch 3/20
# 1405/1405 - 5s - 4ms/step - loss: 0.2498 - val_loss: 0.1926 - learning_rate: 1.0000e-03
# Epoch 4/20
# 1405/1405 - 5s - 4ms/step - loss: 0.2165 - val_loss: 0.2773 - learning_rate: 1.0000e-03
# Epoch 5/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1994 - val_loss: 0.2292 - learning_rate: 1.0000e-03
# Epoch 6/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1889 - val_loss: 0.2281 - learning_rate: 1.0000e-03
# Epoch 7/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1753 - val_loss: 0.1641 - learning_rate: 2.5000e-04
# Epoch 8/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1695 - val_loss: 0.1725 - learning_rate: 2.5000e-04
# Epoch 9/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1718 - val_loss: 0.1833 - learning_rate: 2.5000e-04
# Epoch 10/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1717 - val_loss: 0.2227 - learning_rate: 2.5000e-04
# Epoch 11/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1637 - val_loss: 0.1618 - learning_rate: 6.2500e-05
# Epoch 12/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1666 - val_loss: 0.1671 - learning_rate: 6.2500e-05
# Epoch 13/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1671 - val_loss: 0.1915 - learning_rate: 6.2500e-05
# Epoch 14/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1632 - val_loss: 0.1600 - learning_rate: 6.2500e-05
# Epoch 15/20
# 1405/1405 - 5s - 3ms/step - loss: 0.1623 - val_loss: 0.1850 - learning_rate: 6.2500e-05
# Epoch 16/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1611 - val_loss: 0.1866 - learning_rate: 6.2500e-05
# Epoch 17/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1673 - val_loss: 0.1668 - learning_rate: 6.2500e-05
# Epoch 18/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1608 - val_loss: 0.1486 - learning_rate: 1.5625e-05
# Epoch 19/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1665 - val_loss: 0.1851 - learning_rate: 1.5625e-05
# Epoch 20/20
# 1405/1405 - 5s - 4ms/step - loss: 0.1599 - val_loss: 0.1660 - learning_rate: 1.5625e-05
# Epoch 1/10
# 1405/1405 - 5s - 3ms/step - loss: -7.1250e-01 - val_loss: -7.6693e-01 - learning_rate: 1.0000e-03
# Epoch 2/10
# 1405/1405 - 4s - 3ms/step - loss: -8.5346e-01 - val_loss: -8.1475e-01 - learning_rate: 1.0000e-03
# Epoch 3/10
# 1405/1405 - 4s - 3ms/step - loss: -8.7226e-01 - val_loss: -8.5158e-01 - learning_rate: 1.0000e-03
# Epoch 4/10
# 1405/1405 - 4s - 3ms/step - loss: -8.8267e-01 - val_loss: -8.0037e-01 - learning_rate: 1.0000e-03
# Epoch 5/10
# 1405/1405 - 4s - 3ms/step - loss: -9.0001e-01 - val_loss: -7.4596e-01 - learning_rate: 1.0000e-03
# Epoch 6/10
# 1405/1405 - 4s - 3ms/step - loss: -9.0633e-01 - val_loss: -8.6153e-01 - learning_rate: 1.0000e-03
# Epoch 7/10
# 1405/1405 - 4s - 3ms/step - loss: -8.9731e-01 - val_loss: -8.4246e-01 - learning_rate: 1.0000e-03
# Epoch 8/10
# 1405/1405 - 4s - 3ms/step - loss: -8.9999e-01 - val_loss: -8.4361e-01 - learning_rate: 1.0000e-03
# Epoch 9/10
# 1405/1405 - 4s - 3ms/step - loss: -9.0893e-01 - val_loss: -8.3977e-01 - learning_rate: 1.0000e-03
# Epoch 10/10
# 1405/1405 - 4s - 3ms/step - loss: -9.0670e-01 - val_loss: -8.2446e-01 - learning_rate: 2.5000e-04
# 11238/11238 ━━━━━━━━━━━━━━━━━━━━ 4s 309us/step
# 2482/2482 ━━━━━━━━━━━━━━━━━━━━ 1s 310us/step
# Ensemble member 5 complete | val NLL: -0.861533

# %%
# combine ensemble members to get overall predictions and uncertainty decomposition
train_mus = np.array(train_mus)    # (M, N, 1)
train_vars = np.array(train_vars)  # (M, N, 1)
test_mus = np.array(test_mus)      # (M, N, 1)
test_vars = np.array(test_vars)    # (M, N, 1)

# Ensemble mean: average of individual means
ensemble_train_mu = np.mean(train_mus, axis=0)
ensemble_test_mu = np.mean(test_mus, axis=0)

# Ensemble variance: (1/M) * sum(sigma_m^2 + mu_m^2) - mu*^2
ensemble_train_var = np.mean(train_vars + train_mus**2, axis=0) - ensemble_train_mu**2
ensemble_test_var = np.mean(test_vars + test_mus**2, axis=0) - ensemble_test_mu**2

# Decompose into aleatoric (data noise) and epistemic (model disagreement)
aleatoric_train = np.mean(train_vars, axis=0)
epistemic_train = np.mean(train_mus**2, axis=0) - ensemble_train_mu**2

aleatoric_test = np.mean(test_vars, axis=0)
epistemic_test = np.mean(test_mus**2, axis=0) - ensemble_test_mu**2

# 95% prediction intervals
z = 1.96
ensemble_train_std = np.sqrt(ensemble_train_var)
ensemble_test_std = np.sqrt(ensemble_test_var)

train_lower = ensemble_train_mu - z * ensemble_train_std
train_upper = ensemble_train_mu + z * ensemble_train_std
test_lower = ensemble_test_mu - z * ensemble_test_std
test_upper = ensemble_test_mu + z * ensemble_test_std

# %%
# Save: [geo, gender, year, age, mu, total_var, aleatoric_var, epistemic_var, lower_95, upper_95]
ensemble_train_output = np.column_stack((
    inputs_train, ensemble_train_mu, ensemble_train_var,
    aleatoric_train, epistemic_train, train_lower, train_upper
))
ensemble_test_output = np.column_stack((
    inputs_test, ensemble_test_mu, ensemble_test_var,
    aleatoric_test, epistemic_test, test_lower, test_upper
))

np.savetxt("../data/dl_country_freeze_ensemble_fitted.txt", ensemble_train_output)
np.savetxt("../data/dl_country_freeze_ensemble_forecast.txt", ensemble_test_output)

print("\nFreeze-and-train ensemble combination complete.")
print(f"Output columns: geo, gender, year, age, mu, total_var, aleatoric_var, epistemic_var, lower_95, upper_95")
print(f"Train shape: {ensemble_train_output.shape}")
print(f"Test shape:  {ensemble_test_output.shape}")
# Out:
# Freeze-and-train ensemble combination complete.
# Output columns: geo, gender, year, age, mu, total_var, aleatoric_var, epistemic_var, lower_95, upper_95
# Train shape: (359594, 10)
# Test shape:  (79400, 10)
